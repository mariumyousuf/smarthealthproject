# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np
import pytz

# %%
patient1=pd.read_csv("Mt5160_SLUM_2017-05-12 092056 copy 2.txt", sep=":" , header=None)

# %%
patient1.head()
# Out:
#            0            1
# 0  PatientID       Mt5160
# 1  Education
# 2        Sex         Male
# 3        DOB   1943/10/06
# 4       Date   2017/05/12

# %%
patient1.columns = ["STStamp", "UNIX_Timestamp"]

# %%
patient1.head()
# Out:
#      STStamp UNIX_Timestamp
# 0  PatientID         Mt5160
# 1  Education
# 2        Sex           Male
# 3        DOB     1943/10/06
# 4       Date     2017/05/12

# %%
patient1.index = patient1.STStamp

# %%
patient1.head()
# Out:
#              STStamp UNIX_Timestamp
# STStamp
# PatientID  PatientID         Mt5160
# Education  Education
# Sex              Sex           Male
# DOB              DOB     1943/10/06
# Date            Date     2017/05/12

# %%
del patient1['STStamp']

# %%
patient1.head()
# Out:
#           UNIX_Timestamp
# STStamp
# PatientID         Mt5160
# Education
# Sex                 Male
# DOB           1943/10/06
# Date          2017/05/12

# %%
start=patient1.loc["STStamp"]
end=patient1.loc["ETStamp"]
shake=patient1.loc["Shake Timestamp"]

# %%
start.head()
# Out:
#          UNIX_Timestamp
# STStamp
# STStamp   1494598860909
# STStamp   1494598878121
# STStamp   1494598889964
# STStamp   1494598966140
# STStamp   1494598978584

# %%
st = start.copy()
st['UNIX_Timestamp'] = st['UNIX_Timestamp'].map(lambda x: x.lstrip(' ').rstrip(''))

# %%
st
# Out:
#         UNIX_Timestamp
# STStamp
# STStamp  1494598860909
# STStamp  1494598878121
# STStamp  1494598889964
# STStamp  1494598966140
# STStamp  1494598978584
# STStamp  1494599031531
# STStamp  1494599081186
# STStamp  1494599117149
# STStamp  1494599200540
# STStamp  1494599221887
# STStamp  1494599307315

# %%
#st = start.copy()
#st['UNIX_Timestamp'] = pd.to_numeric(st.UNIX_Timestamp, downcast='integer')

# %%
# Way 1
st['UNIX_Timestamp'].astype('int').astype("datetime64[ms]")
# Out:
# STStamp
# STStamp   2017-05-12 14:21:00.909
# STStamp   2017-05-12 14:21:18.121
# STStamp   2017-05-12 14:21:29.964
# STStamp   2017-05-12 14:22:46.140
# STStamp   2017-05-12 14:22:58.584
# STStamp   2017-05-12 14:23:51.531
# STStamp   2017-05-12 14:24:41.186
# STStamp   2017-05-12 14:25:17.149
# STStamp   2017-05-12 14:26:40.540
# STStamp   2017-05-12 14:27:01.887
# STStamp   2017-05-12 14:28:27.315
# Name: UNIX_Timestamp, dtype: datetime64[ns]

# %%
# Way 2
UNIXstart = pd.to_datetime(st['UNIX_Timestamp'], unit='ms')#, format="%d/%m/%Y") #D,s,ms,us,ns#

# %%
UNIXstart
# Out:
# STStamp
# STStamp   2017-05-12 14:21:00.909
# STStamp   2017-05-12 14:21:18.121
# STStamp   2017-05-12 14:21:29.964
# STStamp   2017-05-12 14:22:46.140
# STStamp   2017-05-12 14:22:58.584
# STStamp   2017-05-12 14:23:51.531
# STStamp   2017-05-12 14:24:41.186
# STStamp   2017-05-12 14:25:17.149
# STStamp   2017-05-12 14:26:40.540
# STStamp   2017-05-12 14:27:01.887
# STStamp   2017-05-12 14:28:27.315
# Name: UNIX_Timestamp, dtype: datetime64[ns]

# %%
UNIXstart = UNIXstart.dt.tz_localize(tz='US/Pacific').dt.tz_convert(None)

# %%
#UNIXstart = UNIXstart.dt.tz_localize(tz='US/Pacific').dt.tz_convert(None)

# %%
UNIXstart
# Out:
# STStamp
# STStamp   2017-05-12 21:21:00.909
# STStamp   2017-05-12 21:21:18.121
# STStamp   2017-05-12 21:21:29.964
# STStamp   2017-05-12 21:22:46.140
# STStamp   2017-05-12 21:22:58.584
# STStamp   2017-05-12 21:23:51.531
# STStamp   2017-05-12 21:24:41.186
# STStamp   2017-05-12 21:25:17.149
# STStamp   2017-05-12 21:26:40.540
# STStamp   2017-05-12 21:27:01.887
# STStamp   2017-05-12 21:28:27.315
# Name: UNIX_Timestamp, dtype: datetime64[ns]

# %%
UNIXstart.plot()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#plt.style.use('seaborn')

# %%
pressure_data = pd.read_csv("9SensChairData51291915.txt", sep=",", header=None)

# %%
pressure_data.head()
# Out:
#                          0  1    2    3    4    5    6    7     8
# 0  [ 12/05/2017 09:19:36 ]  1  270  591    7    7  175  101  2053
# 1  [ 12/05/2017 09:19:36 ]  1   47  258  534  127  745  102  2053
# 2  [ 12/05/2017 09:19:36 ]  2   50  261  541  120  746  102  2053
# 3  [ 12/05/2017 09:19:36 ]  2  280  599    6    6  175  101  2053
# 4  [ 12/05/2017 09:19:36 ]  3   59  260  544  109  749  102  2053

# %%
pressure_data.columns = ['time_stamp','sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5', 
                         'sensor_6', 'sensor_7', 'sensor_8']

# %%
pressure_data.head()
# Out:
#                 time_stamp  sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# 0  [ 12/05/2017 09:19:36 ]         1       270       591         7         7
# 1  [ 12/05/2017 09:19:36 ]         1        47       258       534       127
# 2  [ 12/05/2017 09:19:36 ]         2        50       261       541       120
# 3  [ 12/05/2017 09:19:36 ]         2       280       599         6         6
# 4  [ 12/05/2017 09:19:36 ]         3        59       260       544       109
#
#    sensor_6  sensor_7  sensor_8
# 0       175       101      2053
# 1       745       102      2053
# 2       746       102      2053
# 3       175       101      2053
# 4       749       102      2053

# %%
pressure_data['time_stamp'] = pressure_data['time_stamp'].map(lambda x: x.lstrip('[').rstrip(''))

# %%
pressure_data['time_stamp'] = pressure_data['time_stamp'].map(lambda x: x.rstrip(']').rstrip(''))

# %%
pressure_data.head()
# Out:
#               time_stamp  sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# 0   12/05/2017 09:19:36          1       270       591         7         7
# 1   12/05/2017 09:19:36          1        47       258       534       127
# 2   12/05/2017 09:19:36          2        50       261       541       120
# 3   12/05/2017 09:19:36          2       280       599         6         6
# 4   12/05/2017 09:19:36          3        59       260       544       109
#
#    sensor_6  sensor_7  sensor_8
# 0       175       101      2053
# 1       745       102      2053
# 2       746       102      2053
# 3       175       101      2053
# 4       749       102      2053

# %%
pressure_data['time_stamp'] = pd.to_datetime(pressure_data['time_stamp'])

# %%
pressure_data.head()
# Out:
#            time_stamp  sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# 0 2017-12-05 09:19:36         1       270       591         7         7
# 1 2017-12-05 09:19:36         1        47       258       534       127
# 2 2017-12-05 09:19:36         2        50       261       541       120
# 3 2017-12-05 09:19:36         2       280       599         6         6
# 4 2017-12-05 09:19:36         3        59       260       544       109
#
#    sensor_6  sensor_7  sensor_8
# 0       175       101      2053
# 1       745       102      2053
# 2       746       102      2053
# 3       175       101      2053
# 4       749       102      2053

# %%
pressure_data['time_stamp'].dt.time
# Out:
# 0        09:19:36
# 1        09:19:36
# 2        09:19:36
# 3        09:19:36
102      2053
# 2017-12-05 09:19:40         6         6       174       101      2053
# 2017-12-05 09:19:40       572        98       753       102      2053
# 2017-12-05 09:19:40         6         6       174       101      2053
# 2017-12-05 09:19:41       571        94       754       102      2053
# 2017-12-05 09:19:41         6         6       174       101      2053
# 2017-12-05 09:19:41       570        88       755       102      2053
# 2017-12-05 09:19:41         6         6       175       101      2053
# 2017-12-05 09:19:41       573        83       754       102      2053

# %%
del pressure_data['time_stamp']

# %%
pressure_data.head()
# Out:
#                      sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  \
# time_stamp
# 2017-12-05 09:19:36         1       270       591         7         7
# 2017-12-05 09:19:36         1        47       258       534       127
# 2017-12-05 09:19:36         2        50       261       541       120
# 2017-12-05 09:19:36         2       280       599         6         6
# 2017-12-05 09:19:36         3        59       260       544       109
#
#                      sensor_6  sensor_7  sensor_8
# time_stamp
# 2017-12-05 09:19:36       175       101      2053
# 2017-12-05 09:19:36       745       102      2053
# 2017-12-05 09:19:36       746       102      2053
# 2017-12-05 09:19:36       175       101      2053
# 2017-12-05 09:19:36       749       102      2053

# %%
sensor_1 = pressure_data.sensor_1
sensor_2 = pressure_data.sensor_2
sensor_3 = pressure_data.sensor_3
sensor_4 = pressure_data.sensor_4
sensor_5 = pressure_data.sensor_5
sensor_6 = pressure_data.sensor_6
sensor_7 = pressure_data.sensor_7
sensor_8 = pressure_data.sensor_8

# %%
sensor_1_ = pressure_data.sensor_1
# 
# '2017-05-06 15:43:31':'2017-05-06 15:52:03'
# ['2017-05-06 15:43:31':'2017-05-06 15:52:03']

# %%
sensor_1.head()
# Out:
# time_stamp
# 2017-12-05 09:19:36    1
# 2017-12-05 09:19:36    1
# 2017-12-05 09:19:36    2
# 2017-12-05 09:19:36    2
# 2017-12-05 09:19:36    3
# Name: sensor_1, dtype: int64

# %%
#avgtime = MLX75305ts.groupby(MLX75305ts.index.time).mean()
avgSensor1 = sensor_1.groupby(sensor_1.index.time).mean()
avgSensor2 = sensor_2.groupby(sensor_2.index.time).mean()
avgSensor3 = sensor_3.groupby(sensor_3.index.time).mean()
avgSensor4 = sensor_4.groupby(sensor_4.index.time).mean()
avgSensor5 = sensor_5.groupby(sensor_5.index.time).mean()
avgSensor6 = sensor_6.groupby(sensor_6.index.time).mean()
avgSensor7 = sensor_7.groupby(sensor_7.index.time).mean()
avgSensor8 = sensor_8.groupby(sensor_8.index.time).mean()

# %%
avgSensor1.plot(label="Sensor 1", legend=True)
avgSensor2.plot(label="Sensor 2", legend=True)
avgSensor3.plot(label="Sensor 3", legend=True)
avgSensor4.plot(label="Sensor 4", legend=True)
avgSensor5.plot(label="Sensor 5", legend=True)
avgSensor6.plot(label="Sensor 6", legend=True)
avgSensor7.plot(label="Sensor 7", legend=True)
avgSensor8.plot(label="Sensor 8", legend=True)

fig = plt.gcf()
plt.yscale('symlog')
fig.set_size_inches(20,5)

# %%
#avgSensor1.plot(label="Sensor 1", legend=True)
avgSensor2.plot(label="Sensor 2", legend=True)
avgSensor3.plot(label="Sensor 3", legend=True)
avgSensor4.plot(label="Sensor 4", legend=True)
avgSensor5.plot(label="Sensor 5", legend=True)
avgSensor6.plot(label="Sensor 6", legend=True)
#avgSensor7.plot(label="Sensor 7", legend=True)
#avgSensor8.plot(label="Sensor 8", legend=True)
UNIXstart.plot
fig = plt.gcf()
plt.yscale('symlog')
fig.set_size_inches(20,5)

# %%
UNIXstart
